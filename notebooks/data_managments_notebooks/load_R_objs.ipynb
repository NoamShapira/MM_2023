# %%
library(metacell)

# %% [markdown]
# # re-save feats used by MC

# %%
spid_feats <- get(load(file='/home/labs/amit/shuangyi/Project_MM3/Atlas/data_MM_SPID_20231110_CD45/gset.test_feats.Rda'))
mars_feats <- get(load(file='/home/labs/amit/shuangyi/Project_MM3/Atlas/data_MM_MARS_20230713_CD45/gset.test_feats.Rda'))

# %%
pc_spid_feats <- get(load(file='/home/labs/amit/shuangyi/Project_MM3/Atlas/data_MM_SPID_20240519_PC_250/gset.test_feats.Rda'))
pc_mars_feats <- get(load(file='/home/labs/amit/shuangyi/Project_MM3/Atlas/data_MM_MARS_20230713_PC/gset.test_feats.Rda'))

# %%
csv_SPID_genes_path <- '/home/labs/amit/noamsh/data/mm_2023/feats/spid_genes.csv'
csv_MARS_genes_path <- '/home/labs/amit/noamsh/data/mm_2023/feats/mars_genes.csv'
mars_feats
# Out:
# An object of class "tgGeneSets"
# Slot "description":
# [1] "test_feats"
#
# Slot "set_names":
# [1] 1
#
# Slot "gene_set":
#        A1BG         A2M       ABCA2       ABCA7       ABCB1       ABCC9
#           1           1           1           1           1           1
#       ABCD2       ABCF1      ABLIM1       ACACB      ACAD11       ACAP1
#           1           1           1           1           1           1
#       ACRBP       ACSF2       ACSL6        ACTB       ACTG2       ACTR8
#           1           1           1           1           1           1
#      ACVR2B        ACY3      ADAM28       ADAM9     ADAMTS5   ADAMTS7P4
#           1           1           1           1           1           1
#       ADCK5      ADGRE3      ADGRG1      ADGRG3      ADGRG5      ADGRG6
#           1           1           1           1           1           1
#      ADGRL4       ADH1B     ADIPOR1       ADTRP       AFAP1     AFAP1L2
# ...

# %%
write.csv(spid_feats@gene_set,file=csv_SPID_genes_path,fileEncoding = "UTF-8")

# %%
write.csv(mars_feats@gene_set,file=csv_MARS_genes_path,fileEncoding = "UTF-8")

# %%
write.csv(pc_spid_feats@gene_set,file='/home/labs/amit/noamsh/data/mm_2023/feats/pc_spid_genes.csv',fileEncoding = "UTF-8")
write.csv(pc_mars_feats@gene_set,file='/home/labs/amit/noamsh/data/mm_2023/feats/pc_mars_genes.csv',fileEncoding = "UTF-8")

# %% [markdown]
# # re-save cells

# %% [markdown]
# ### PC

# %%
# spid_PC <- readRDS('/home/labs/amit/shuangyi/Project_MM_2023/cells_MM_SPID_20231110_PC.Rds')
# mars_PC <- readRDS('/home/labs/amit/shuangyi/Project_MM_2023/cells_MM_MARS_20231110_PC.Rds')

spid_PC <- readRDS('/home/labs/amit/shuangyi/Project_MM3/Atlas/cells_MM_SPID_20240326_PC.Rds')
mars_PC <- readRDS('/home/labs/amit/shuangyi/Project_MM3/Atlas/cells_MM_MARS_20230713_PC.Rds')

# %%
length(spid_PC)
# spid_PC
# Out:
# [1] 58112

# %% [markdown]
# ### CD45

# %%
# spid_CD45 <- readRDS('/home/labs/amit/shuangyi/Project_MM_2023/cells_MM_SPID_20231110_CD45.Rds')
# mars_CD45 <- readRDS('/home/labs/amit/shuangyi/Project_MM_2023/cells_MM_MARS_20231110_CD45.Rds')

spid_CD45 <- readRDS('/home/labs/amit/shuangyi/Project_MM3/Atlas/cells_MM_SPID_20240326_CD45.Rds')
mars_CD45 <- readRDS('/home/labs/amit/shuangyi/Project_MM3/Atlas/cells_MM_MARS_20230713_CD45.Rds')

# %%
length(spid_CD45)
# spid_CD45
# Out:
# [1] 169870

# %% [markdown]
# ### malignant

# %%
spid_malignant <- readRDS('/home/labs/amit/shuangyi/Project_MM3/Atlas/cells_MM_SPID_20240201_PC_malignant.Rds')
mars_malignant <- readRDS('/home/labs/amit/shuangyi/Project_MM3/Atlas/cells_MM_MARS_20230713_PC_malignant.Rds')

# %%
# spid_malignant

# %% [markdown]
# ### save

# %%
csv_SPID_PC_cells_path <- '/home/labs/amit/noamsh/data/mm_2023/cells/spid_PC_cells.csv'
csv_MARS_PC_cells_path <- '/home/labs/amit/noamsh/data/mm_2023/cells/mars_PC_cells.csv'

csv_SPID_CD45_cells_path <- '/home/labs/amit/noamsh/data/mm_2023/cells/spid_CD45_cells.csv'
csv_MARS_CD45_cells_path <- '/home/labs/amit/noamsh/data/mm_2023/cells/mars_CD45_cells.csv'

csv_SPID_PC_malingnant_cells_path <- '/home/labs/amit/noamsh/data/mm_2023/cells/spid_PC_malingnant_cells.csv'
csv_MARS_PC_malingnant_cells_path <- '/home/labs/amit/noamsh/data/mm_2023/cells/mars_PC_malingnant_cells.csv'

# %%
write.csv(spid_CD45, file=csv_SPID_CD45_cells_path, fileEncoding = "UTF-8")
write.csv(mars_CD45, file=csv_MARS_CD45_cells_path, fileEncoding = "UTF-8")

write.csv(spid_PC, file=csv_SPID_PC_cells_path, fileEncoding = "UTF-8")
write.csv(mars_PC, file=csv_MARS_PC_cells_path, fileEncoding = "UTF-8")

write.csv(spid_malignant, file=csv_SPID_PC_malingnant_cells_path, fileEncoding = "UTF-8")
write.csv(mars_malignant, file=csv_MARS_PC_malingnant_cells_path, fileEncoding = "UTF-8")

# %%
# write.csv(spid_malignant, file=csv_SPID_PC_malingnant_cells_path, fileEncoding = "UTF-8")
# write.csv(mars_malignant, file=csv_MARS_PC_malingnant_cells_path, fileEncoding = "UTF-8")
